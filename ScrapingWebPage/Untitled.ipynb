# %%
import pandas as pd

# %%
df = pd.read_csv('Quotes.csv')

# %%
df
# Out:
#    Unnamed: 0                                              quote  \
# 0           0  The world as we have created it is a process o...
# 1           1  It is our choices, Harry, that show what we tr...
# 2           2  There are only two ways to live your life. One...
# 3           3  The person, be it gentleman or lady, who has n...
# 4           4  Imperfection is beauty, madness is genius and ...
# 5           5  Try not to become a man of success. Rather bec...
# 6           6  It is better to be hated for what you are than...
# 7           7  I have not failed. I've just found 10,000 ways...
# 8           8  A woman is like a tea bag; you never know how ...
# 9           9   A day without sunshine is like, you know, night.
#
#               author                  author_id  \
# 0    Albert Einstein    /author/Albert-Einstein
# 1       J.K. Rowling        /author/J-K-Rowling
# 2    Albert Einstein    /author/Albert-Einstein
# 3        Jane Austen        /author/Jane-Austen
# ...

# %%
del df['quote']
del df['author_id']
del df['tags']

# %%
df
# Out:
#    Unnamed: 0             author
# 0           0    Albert Einstein
# 1           1       J.K. Rowling
# 2           2    Albert Einstein
# 3           3        Jane Austen
# 4           4     Marilyn Monroe
# 5           5    Albert Einstein
# 6           6         André Gide
# 7           7   Thomas A. Edison
# 8           8  Eleanor Roosevelt
# 9           9       Steve Martin
